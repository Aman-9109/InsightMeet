# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.summarization import MeetingSummarizer

# %%
import json

with open("../data/processed/chunks.json", "r", encoding="utf-8") as f:
    chunks = json.load(f)

# %%
chunk_summaries = summarizer.summarize_chunks(chunks)

final_summary = summarizer.refine_summary(chunk_summaries)

print("\nFinal Meeting Summary:\n")
print(final_summary)
# Out:
# Your max_length is set to 150, but your input_length is only 35. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Your max_length is set to 200, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Final Meeting Summary:
#
# Al pastor favorite Zestful Food hot cross bun. Old beer lingers takes heat bring odor cold dip restores health zest salt pickle tastes fine ham tacos al pastor favorite zestful food hot cross Bun. stale smell old beer lingered takes heat take odor cold Dip restores healthZest salt Pickle tastesfine ham tacos

# %%
output_path = "../data/processed/summary_results.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump({
        "chunk_summaries": chunk_summaries,
        "final_summary": final_summary
    }, f, indent=4)

print("Summary saved successfully ✅")
# Out:
# Summary saved successfully ✅
