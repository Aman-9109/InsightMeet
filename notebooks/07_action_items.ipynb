# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
with open("../data/processed/transcript.txt", "r", encoding="utf-8") as f:
    transcript = f.read()

print(transcript[:500])
# Out:
#  The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Tacos al pastor are my favorite. A zestful food is the hot cross bun.

# %%
from src.action_items import ActionItemExtractor

extractor = ActionItemExtractor()

results = extractor.structured_output(transcript)

print("Action Items:\n")
print(results["action_items"])

print("\nDecisions:\n")
print(results["decisions"])
# Out:
# Action Items:
#
# []
#
# Decisions:
#
# []

# %%
import json

output_path = "../data/processed/action_items.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4)

print("Action items saved successfully ✅")
# Out:
# Action items saved successfully ✅
